# %% [markdown]
# **PENJUALAN TAHUN 2020-2023**

# %%
#library
import pandas as pd
import numpy as np

#visualisasi data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#menamilkan data and create dataframe

df = pd.read_csv('datapenjualan20202023.csv')
df.head(20)
# Out:
#      1  1/2/2020                                     TOKO MURAH  \
# 0    2  1/2/2020                                     TOKO MURAH
# 1    3  1/2/2020                          TOKO APRILIA SUKRISNI
# 2    4  1/2/2020                          TOKO APRILIA SUKRISNI
# 3    5  1/2/2020                          TOKO APRILIA SUKRISNI
# 4    6  1/2/2020                                TOKO MAJU TERUS
# 5    7  1/2/2020                                TOKO MAJU TERUS
# 6    8  1/2/2020                                TOKO MAJU TERUS
# 7    9  1/3/2020                            KOPERASI BRI MELAWI
# 8   10  1/3/2020                            KOPERASI BRI MELAWI
# 9   11  1/3/2020                            KOPERASI BRI MELAWI
# 10  12  1/6/2020                                       TOKO DEB
# 11  13  1/6/2020                                       TOKO DEB
# 12  14  1/6/2020                           TOKO FATHULLAH ZIKRI
# 13  15  1/6/2020                           TOKO FATHULLAH ZIKRI
# ...

# %%
#jumlah baris dan kolom
df.shape
# Out:
# (221, 15)

# %%
#melihat colums
df.columns
# Out:
# Index(['1', '1/2/2020', 'TOKO MURAH', 'JAM LOKESWARA', '1000', '9840000',
#        'Jakarta', '106.82274', '-6.17447', 'ID', 'Asia', 'Jakarta.1', 'ID-JI',
#        'POINT (-6.17447 106.82274)', 'WIB+07:00'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 1          1000       9840000   106.82274    -6.17447
# count  221.000000    221.000000  2.210000e+02  221.000000  221.000000
# mean   112.000000   1814.049774  1.316626e+07   77.179922   29.423496
# std     63.941379   3459.657546  2.559275e+07   50.146452   54.901683
# min      2.000000      4.000000  9.200000e+04   -8.652500   -8.652500
# 25%     57.000000    120.000000  2.943600e+06    1.490060   -6.921550
# 50%    112.000000    500.000000  5.607900e+06  106.822740   -1.357900
# 75%    167.000000   1180.000000  1.050000e+07  109.344750  100.363260
# max    222.000000  18000.000000  1.575000e+08  140.703740  140.703740

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   1                           221 non-null    int64
#  1   1/2/2020                    221 non-null    object
#  2   TOKO MURAH                  221 non-null    object
#  3   JAM LOKESWARA               221 non-null    object
#  4   1000                        221 non-null    int64
#  5   9840000                     221 non-null    float64
#  6   Jakarta                     221 non-null    object
#  7   106.82274                   221 non-null    float64
#  8   -6.17447                    221 non-null    float64
#  9   ID                          221 non-null    object
#  10  Asia                        221 non-null    object
#  11  Jakarta.1                   221 non-null    object
#  12  ID-JI                       163 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#terdapat ketidak samaan jumlah data(missing value)
df.isnull().sum()
# Out:
# 1                              0
# 1/2/2020                       0
# TOKO MURAH                     0
# JAM LOKESWARA                  0
# 1000                           0
# 9840000                        0
# Jakarta                        0
# 106.82274                      0
# -6.17447                       0
# ID                             0
# Asia                           0
# Jakarta.1                      0
# ID-JI                         58
# POINT (-6.17447 106.82274)     0
# WIB+07:00                      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Feature Engineering

# %%
dfnew=df

# %%
dfnew['ID'].replace("Indonesia", "ID", inplace=True)

# %%
dfnew.head(2)
# Out:
#    1  1/2/2020             TOKO MURAH  JAM LOKESWARA  1000     9840000  \
# 0  2  1/2/2020             TOKO MURAH  BATIK LONTARA   120   8400000.0
# 1  3  1/2/2020  TOKO APRILIA SUKRISNI  JAM LOKESWARA  6000  62910000.0
#
#     Jakarta  106.82274  -6.17447  ID  Asia   Jakarta.1  ID-JI  \
# 0   Bandung  107.61102  -6.92155  ID  Asia  Jawa Barat  ID-SU
# 1  Surabaya  112.73783  -7.24597  ID  Asia  Jawa Timur  ID-YO
#
#    POINT (-6.17447 106.82274)   WIB+07:00
# 0  POINT (-6.92155 107.61102)   WIB+07:00
# 1  POINT (-7.24597 112.73783)  WITA+08:00

# %%
dfnew.rename(columns={'1': 'ID', '1/2/2020': 'Date', 'TOKO MURAH': 'Name_Toko', 'JAM LOKESWARA': 'Produk', '1000': 'Kuantitas', '9840000': 'Pendapatan', 'Jakarta': 'Kota', '106.82274': 'Bujur', '-6.17447': 'Lintang', 'ID': 'Code_Kota', 'Asia': 'Benua', 'Jakarta.1': 'Provinsi', 'ID-JI': 'Prov_Code', 'POINT (-6.17447 106.82274)': 'Lokasi', 'WIB+07:00': 'Zona_Waktu'}, inplace=True)

# %%
dfnew.head(1)
# Out:
#    ID      Date   Name_Toko         Produk  Kuantitas  Pendapatan     Kota  \
# 0   2  1/2/2020  TOKO MURAH  BATIK LONTARA        120   8400000.0  Bandung
#
#        Bujur  Lintang Code_Kota Benua    Provinsi Prov_Code  \
# 0  107.61102 -6.92155        ID  Asia  Jawa Barat     ID-SU
#
#                        Lokasi Zona_Waktu
# 0  POINT (-6.92155 107.61102)  WIB+07:00

# %%
dfnew.duplicated().sum()
# Out:
# 0

# %%
dfnew.drop_duplicates()
# Out:
#       ID         Date              Name_Toko          Produk  Kuantitas  \
# 0      2     1/2/2020             TOKO MURAH   BATIK LONTARA        120
# 1      3     1/2/2020  TOKO APRILIA SUKRISNI   JAM LOKESWARA       6000
# 2      4     1/2/2020  TOKO APRILIA SUKRISNI        JAM WISH        408
# 3      5     1/2/2020  TOKO APRILIA SUKRISNI   BATIK BESUREK        140
# 4      6     1/2/2020        TOKO MAJU TERUS   JAM LOKESWARA        820
# ..   ...          ...                    ...             ...        ...
# 216  218   2023-02-08           TOKO SANTOSO   JAM LOKESWARA        260
# 217  219   2023-03-08           TOKO SANTOSO   BATIK LONTARA         70
# 218  220   2023-04-08           TOKO SANTOSO        JAM WISH        350
# 219  221   2023-05-08              TOKO JAYA   BATIK LONTARA         90
# 220  222   2023-06-08              TOKO JAYA   JAM LOKESWARA        500
#
#      Pendapatan        Kota      Bujur    Lintang Code_Kota  Benua  \
# ...

# %%
new_data = {'ID': 1,
            'Date': '1/2/2020',
            'Name_Toko': 'TOKO Murah',
            'Produk': 'JAM LOKESWARA',
            'Kuantitas': 1000,
            'Pendapatan': 9840000,
            'Kota': 'Jakarta',
            'Bujur': 106.82274,
            'Lintang': -6.17447,
            'Code_Kota': 'ID',
            'Benua': 'Asia',
            'Provinsi': 'Jakarta',
            'Prov_Code': 'ID-JI',
            'Lokasi': 'POINT (-6.17447 106.82274)',
            'Zona_Waktu': 'WIB+07:00'}
dfnew = dfnew.append(new_data, ignore_index=True)

# %%
dfnew.tail()
# Out:
#       ID         Date      Name_Toko          Produk  Kuantitas  Pendapatan  \
# 217  219   2023-03-08   TOKO SANTOSO   BATIK LONTARA         70   4900000.0
# 218  220   2023-04-08   TOKO SANTOSO        JAM WISH        350   4900000.0
# 219  221   2023-05-08      TOKO JAYA   BATIK LONTARA         90   6300000.0
# 220  222   2023-06-08      TOKO JAYA   JAM LOKESWARA        500   4700000.0
# 221    1     1/2/2020     TOKO Murah   JAM LOKESWARA       1000   9840000.0
#
#            Kota      Bujur    Lintang Code_Kota  Benua           Provinsi  \
# 217   Pontianak   -0.02269  109.34475        ID   Asia   Kalimantan Barat
# 218    Jayapura   -2.53875  140.70374        ID   Asia              Papua
# 219       Ambon   -3.69594  128.17879        ID   Asia             Maluku
# 220      Padang   -0.92476  100.36326        ID   Asia     Sumatera Barat
# 221     Jakarta  106.82274   -6.17447        ID   Asia            Jakarta
#
#     Prov_Code                      Lokasi  Zona_Waktu
# ...

# %%
#karena kesalahan tadi ada kolom yang aneh jadi perlu dihapus(hapus kolom)
#dfnew.drop(['Zona Waktu', 'kota'], axis=1, inplace=True)
#menghapus baris 222
#dfnew = dfnew.drop(222)

# %%
dfnew.shape
# Out:
# (222, 15)

# %%
dfnew.isnull().sum()
# Out:
# ID             0
# Date           0
# Name_Toko      0
# Produk         0
# Kuantitas      0
# Pendapatan     0
# Kota           0
# Bujur          0
# Lintang        0
# Code_Kota      0
# Benua          0
# Provinsi       0
# Prov_Code     58
# Lokasi         0
# Zona_Waktu     0
# dtype: int64

# %%
#melihat letak baris dan kolom yang mengandung missing value
dfnew[dfnew.isnull().any(axis=1)].sort_values(by='Prov_Code', ascending=False)
# Out:
#       ID       Date                Name_Toko         Produk  Kuantitas  \
# 61    63  1/20/2020                TOKO AQIL  BATIK BESUREK         40
# 62    64  1/20/2020              TOKO ABIZAR  JAM LOKESWARA        700
# 63    65  1/21/2020         TOKO SARDIYANTO   JAM LOKESWARA        500
# 64    66  1/21/2020  TOKO DIDIK PRIOJADMIKO   JAM LOKESWARA        750
# 65    67  1/21/2020         TOKO KIAN KIONG   JAM LOKESWARA       2000
# 66    68  1/21/2020      TOKO ANDREAS INDAH   JAM LOKESWARA       4000
# 67    69  1/21/2020   TOKO EKA SAPUTRA JAYA   JAM LOKESWARA       1000
# 68    70  1/21/2020      TOKO FAKHLI HARUDI   JAM LOKESWARA       2400
# 69    71  1/22/2020                     ANDY  JAM LOKESWARA        250
# 70    72  1/22/2020                     ANDY  BATIK LONTARA        100
# 71    73  1/22/2020                TOKO IFAL  JAM LOKESWARA        250
# 72    74  1/22/2020                TOKO IFAL  BATIK LONTARA        100
# ...

# %%
#lebih simpel untuk melihat nilai missing value
dfnew[dfnew.isnull().any(axis=1)].sort_values(by='Prov_Code', ascending=False)[['Kota', 'Provinsi', 'Prov_Code']]
# Out:
#            Kota          Provinsi Prov_Code
# 61   Yogyakarta        Yogyakarta       NaN
# 62        Medan    Sumatera Utara       NaN
# 63      Jakarta       DKI Jakarta       NaN
# 64      Bandung        Jawa Barat       NaN
# 65     Surabaya        Jawa Timur       NaN
# 66      Makasar  Sulawesi Selatan       NaN
# 67    Pontianak  Kalimantan Barat       NaN
# 68     Denpasar              Bali       NaN
# 69      Jakarta       DKI Jakarta       NaN
# 70     Surabaya        Jawa Timur       NaN
# 71      Bandung        Jawa Barat       NaN
# 72   Yogyakarta        Yogyakarta       NaN
# 73        Medan    Sumatera Utara       NaN
# 74    Pontianak  Kalimantan Barat       NaN
# 75      Jakarta       DKI Jakarta       NaN
# 76      Bandung        Jawa Barat       NaN
# 77     Surabaya        Jawa Timur       NaN
# 78      Makasar  Sulawesi Selatan       NaN
# 79     Surabaya           Jakarta       NaN
# 80   Yogyakarta           Jakarta       NaN
# ...

# %%
dfnew[(dfnew['Kota'] == 'Jakarta')]
# Out:
#       ID       Date               Name_Toko         Produk  Kuantitas  \
# 25    27   1/9/2020              Harya Sari       JAM WISH         20
# 42    44  1/13/2020              TOKO MUNIR  JAM LOKESWARA        300
# 52    54  1/16/2020              TOKO REVAN  JAM LOKESWARA        550
# 56    58  1/20/2020            SAHABAT ANDA  JAM LOKESWARA        900
# 63    65  1/21/2020        TOKO SARDIYANTO   JAM LOKESWARA        500
# 69    71  1/22/2020                    ANDY  JAM LOKESWARA        250
# 75    77  1/23/2020    TOKO ANDRI SUGIANTO   JAM LOKESWARA      10000
# 84    86   2/6/2020     TOKO JESAYA GINTING  JAM LOKESWARA        500
# 91    93   2/7/2020   TOKO BERKAH DUA PUTRA  JAM LOKESWARA      15000
# 99   101   2/9/2020       TOKO WARUNG SANTI  JAM LOKESWARA        540
# 106  108  2/10/2020        TOKO JAYA MAKMUR  JAM LOKESWARA       1000
# 112  114  2/11/2020   TOKO YENNI SUSILAWATI  JAM LOKESWARA         80
# ...

# %% [markdown]
# terdapat bebrapa kolom yang tidak singkron salah satunya pada kolom provinsi salah satunya **jakarta dengan provinsi java**

# %%
#melihat singkronisasi antara kota dengan profinsi
dfnew['Kota'].value_counts()
# Out:
# Surabaya        23
# Jakarta         21
# Bandung         19
# Medan           15
# Yogyakarta      14
# Denpasar        13
# Pontianak       12
#  Ambon           8
#  Jayapura        8
#  Pontianak       8
#  Manado          8
#  Padang          8
# Makasar          8
# Semarang         8
# Lampung          4
# Surakarta        4
# Padang           3
# Banjarmasin      3
# Mataram          3
# Palembang        3
# Batam            3
# Makassar         3
# Samarinda        2
# Depok            2
# Malang           2
# Pekanbaru        2
# Jayapura         2
# palembang        1
#  Medan           1
# Bekasi           1
#  Jakarta         1
#  Bandung         1
#  Palembang       1
#  Semarang        1
#  Surakarta       1
#  Denpasar        1
#  Banjarmasin     1
#  Makasar         1
# Tangerang        1
#  Yogyakarta      1
# Name: Kota, dtype: int64

# %%
#mari kita cek dalam setiap kota apakakah ada kesalahan
#cek kota sby
filtered_df =  dfnew[dfnew['Kota'].isin(['Surabaya', 'Jakarta', 'Bandung', 'Yogyakarta', 'Denpasar', 'Pontianak'])]
filtered_df.sort_values(by='Kota').head(50)
# Out:
#       ID       Date                     Name_Toko         Produk  Kuantitas  \
# 0      2   1/2/2020                    TOKO MURAH  BATIK LONTARA        120
# 132  134  2/11/2020             TOKO RIZKI SAKYAH  BATIK LONTARA         20
# 51    53  1/14/2020                       KARUNIA  BATIK LONTARA         20
# 136  138  2/12/2020                   TOKO RAHMAD  BATIK LONTARA         20
# 59    61  1/20/2020                     TOKO AQIL  JAM LOKESWARA        800
# 48    50  1/13/2020                TOKO KHET MEN   JAM LOKESWARA       1000
# 64    66  1/21/2020       TOKO DIDIK PRIOJADMIKO   JAM LOKESWARA        750
# 140  142  2/17/2020                     TOKO IRVA  BATIK LONTARA         20
# 54    56  1/16/2020                  TOKO DOA IBU  JAM LOKESWARA        500
# 39    41  1/10/2020              Warung Nak Zihan  BATIK LONTARA        100
# 101  103   2/9/2020           TOKO JESAYA GINTING  JAM LOKESWARA      15000
# ...

# %%
filtered_df2 =  dfnew[dfnew['Kota'].isin(['Medan', 'Ambon', 'Jayapura', 'Padang', 'Makasar', 'Semarang'])]
filtered_df2.sort_values(by='Kota')
# Out:
#       ID       Date                                      Name_Toko  \
# 36    38  1/14/2020                                TOKO KEDAI YUDA
# 16    18   1/7/2020                                TOKO KEDAI YUDA
# 66    68  1/21/2020                            TOKO ANDREAS INDAH
# 78    80  1/27/2020                                   TOKO HIDAYAH
# 58    60  1/20/2020                                   SAHABAT ANDA
# 47    49  1/13/2020                            TOKO ANDREAS INDAH
# 34    36  1/13/2020                                     TOKO FAHRI
# 169  171  2/25/2020                                 TOKO SILVIANA
# 14    16   1/6/2020                                     TOKO FAHRI
# 5      7   1/2/2020                                TOKO MAJU TERUS
# 88    90   2/6/2020                             TOKO ANDREAS INDAH
# 160  162  2/21/2020                               TOKO NURFADILAH
# 149  151  2/20/2020                                 TOKO AGUSTINUS
# ...

# %% [markdown]
# setelah beberapa cara untuk menulusuri data ternyata pada kolom **Kota** dengan **Provinsi** tidak singkron jadi untuk memperbaiki nilai kososng pada kolom Prov Code mengalami kesusahan Terdapat banyak kesalahan selanjutnya kita melakukan beberapa cara, mari kita ubah kota surabaya berprovinsi jawa timur, yogyakarta, jakarta jawa barat, pontianak kalimantan barat dan masih banyak lainnya nanti kita buat solusi dengan menggunakan fitur condution

# %%
filtered_df3 =  dfnew[dfnew['Kota'].isin(['Padang', 'Banjarmasin', 'Mataram', 'Palembang', 'Batam', 'Makassar'])]
filtered_df3.sort_values(by='Kota').head(50)
# Out:
#       ID       Date                                      Name_Toko  \
# 168  170  2/25/2020                                 TOKO SILVIANA
# 157  159  2/21/2020                         TOKO ENDANG SUSILAWATI
# 146  148  2/20/2020                                   TOKO SUKARDI
# 10    12   1/6/2020                                       TOKO DEB
# 30    32  1/13/2020                                       TOKO DEB
# 128  130  2/10/2020                         TOKO DIDIK PRIOJADMIKO
# 147  149  2/20/2020                            TOKO ANDRI SUGIANTO
# 158  160  2/21/2020                               TOKO DEWI AFRITA
# 123  125   2/7/2020                                  TOKO KHET MEN
# 19    21   1/7/2020  TOKO KOPERASI KONSUMEN SYARIAH BERKAH BERSEMI
# 17    19   1/7/2020                                TOKO KEDAI YUDA
# 37    39  1/14/2020                                TOKO KEDAI YUDA
# 32    34  1/13/2020                           TOKO FATHULLAH ZIKRI
# ...

# %%
conditions = [
    (dfnew['Kota'] == 'Surabaya'), #laris (1)
    (dfnew['Kota'] == 'Yogyakarta'),
    (dfnew['Kota'] == 'Jakarta'),
    (dfnew['Kota'] == 'Pontianak'),
    (dfnew['Kota'] == 'Bandung'),
    (dfnew['Kota'] == 'Denpasar'),
    (dfnew['Kota'] == 'Medan'),
     (dfnew['Kota'] == 'Semarang')###tidak laris (2)
]           #(1)        (2)
choices = ['Jawa Timur', 'Jawa Barat', 'Jawa Barat', 'Kalimantan Barat', 'Jawa Barat', 'Bali', 'Sumatra Utara', 'Jawa Tengah']
dfnew['Provindi'] = np.select(conditions, choices)
dfnew
# Out:
#       ID         Date              Name_Toko          Produk  Kuantitas  \
# 0      2     1/2/2020             TOKO MURAH   BATIK LONTARA        120
# 1      3     1/2/2020  TOKO APRILIA SUKRISNI   JAM LOKESWARA       6000
# 2      4     1/2/2020  TOKO APRILIA SUKRISNI        JAM WISH        408
# 3      5     1/2/2020  TOKO APRILIA SUKRISNI   BATIK BESUREK        140
# 4      6     1/2/2020        TOKO MAJU TERUS   JAM LOKESWARA        820
# ..   ...          ...                    ...             ...        ...
# 217  219   2023-03-08           TOKO SANTOSO   BATIK LONTARA         70
# 218  220   2023-04-08           TOKO SANTOSO        JAM WISH        350
# 219  221   2023-05-08              TOKO JAYA   BATIK LONTARA         90
# 220  222   2023-06-08              TOKO JAYA   JAM LOKESWARA        500
# 221    1     1/2/2020             TOKO Murah   JAM LOKESWARA       1000
#
#      Pendapatan        Kota      Bujur    Lintang Code_Kota  Benua  \
# ...

# %%
#dfnew to dfBaru untuk meminimalisisr kesalahan dalam pengilahan data
dfbaru = dfnew

# %% [markdown]
# **Jakarta**

# %%
dfbaru['Prov_Code'] = np.where((dfbaru['Provinsi'] == 'Jakarta') | (dfbaru['Lintang'] == -6.17447) & (dfbaru['Prov_Code'].isnull()), 'ID-JI', dfbaru['Prov_Code'])

# %%
dfbaru[(dfbaru['Kota'] == 'Jakarta')]
# Out:
#       ID       Date               Name_Toko         Produk  Kuantitas  \
# 25    27   1/9/2020              Harya Sari       JAM WISH         20
# 42    44  1/13/2020              TOKO MUNIR  JAM LOKESWARA        300
# 52    54  1/16/2020              TOKO REVAN  JAM LOKESWARA        550
# 56    58  1/20/2020            SAHABAT ANDA  JAM LOKESWARA        900
# 63    65  1/21/2020        TOKO SARDIYANTO   JAM LOKESWARA        500
# 69    71  1/22/2020                    ANDY  JAM LOKESWARA        250
# 75    77  1/23/2020    TOKO ANDRI SUGIANTO   JAM LOKESWARA      10000
# 84    86   2/6/2020     TOKO JESAYA GINTING  JAM LOKESWARA        500
# 91    93   2/7/2020   TOKO BERKAH DUA PUTRA  JAM LOKESWARA      15000
# 99   101   2/9/2020       TOKO WARUNG SANTI  JAM LOKESWARA        540
# 106  108  2/10/2020        TOKO JAYA MAKMUR  JAM LOKESWARA       1000
# 112  114  2/11/2020   TOKO YENNI SUSILAWATI  JAM LOKESWARA         80
# ...

# %%
# dikarenakan nilai indek tidak berurutan maka menginputdata dengan satu persatu
indeks_baris = [131, 138, 139, 142, 143, 151]  # Indeks baris dimulai dari 0
#mencari nilai kolom
dfbaru.loc[indeks_baris, 'Prov_Code']
# Out:
# 131    ID
# 138    ID
# 139    ID
# 142    ID
# 143    ID
# 151    ID
# Name: Prov_Code, dtype: object

# %% [markdown]
# premis 1 #mengubah id ke id-ji yang sesuai berdasarkan kota, provinsi dan lintang bernilai sama

# %%
#mengubah id keid-ji yang sesuai berdasarkan kota, provinsi dan lintang bernilai sama
dfbaru.loc[indeks_baris, 'Prov_Code']='ID-JI'

# %%
indeks_baris = [131, 138, 139, 142, 143, 151]  # Indeks baris dimulai dari 0
#mencari nilai kolom
dfbaru.loc[indeks_baris, 'Prov_Code']
# Out:
# 131    ID-JI
# 138    ID-JI
# 139    ID-JI
# 142    ID-JI
# 143    ID-JI
# 151    ID-JI
# Name: Prov_Code, dtype: object

# %%
dfbaru[(dfbaru['Kota'] == 'Jakarta')]
# Out:
#       ID       Date               Name_Toko         Produk  Kuantitas  \
# 25    27   1/9/2020              Harya Sari       JAM WISH         20
# 42    44  1/13/2020              TOKO MUNIR  JAM LOKESWARA        300
# 52    54  1/16/2020              TOKO REVAN  JAM LOKESWARA        550
# 56    58  1/20/2020            SAHABAT ANDA  JAM LOKESWARA        900
# 63    65  1/21/2020        TOKO SARDIYANTO   JAM LOKESWARA        500
# 69    71  1/22/2020                    ANDY  JAM LOKESWARA        250
# 75    77  1/23/2020    TOKO ANDRI SUGIANTO   JAM LOKESWARA      10000
# 84    86   2/6/2020     TOKO JESAYA GINTING  JAM LOKESWARA        500
# 91    93   2/7/2020   TOKO BERKAH DUA PUTRA  JAM LOKESWARA      15000
# 99   101   2/9/2020       TOKO WARUNG SANTI  JAM LOKESWARA        540
# 106  108  2/10/2020        TOKO JAYA MAKMUR  JAM LOKESWARA       1000
# 112  114  2/11/2020   TOKO YENNI SUSILAWATI  JAM LOKESWARA         80
# ...

# %%
null = dfbaru[dfbaru.isnull().any(axis=1)].sort_values(by='Kota', ascending=False)[['Kota', 'Lintang', 'Provinsi', 'Prov_Code']]
null
# Out:
#            Kota  Lintang          Provinsi Prov_Code
# 61   Yogyakarta -1.35790        Yogyakarta       NaN
# 72   Yogyakarta -1.35790        Yogyakarta       NaN
# 70     Surabaya -7.24597        Jawa Timur       NaN
# 77     Surabaya -7.24597        Jawa Timur       NaN
# 65     Surabaya -7.24597        Jawa Timur       NaN
# 82    Pontianak -0.02269         Pontianak       NaN
# 67    Pontianak -0.02269  Kalimantan Barat       NaN
# 116   Pontianak -0.02269         Pontianak       NaN
# 110   Pontianak -0.02269         Pontianak       NaN
# 104   Pontianak -0.02269         Pontianak       NaN
# 74    Pontianak -0.02269  Kalimantan Barat       NaN
# 97    Pontianak -0.02269         Pontianak       NaN
# 89    Pontianak -0.02269         Pontianak       NaN
# 73        Medan  3.58967    Sumatera Utara       NaN
# 62        Medan  3.58967    Sumatera Utara       NaN
# 66      Makasar -6.27608  Sulawesi Selatan       NaN
# 78      Makasar -6.27608  Sulawesi Selatan       NaN
# ...

# %% [markdown]
# mengatasi nilai kosong Yogyakarta

# %%
YOG_id = dfbaru[(dfbaru['Lintang']  == -1.35790) & (dfbaru['Provinsi'] == 'Yogyakarta' )]
YOG_id
# Out:
#     ID       Date              Name_Toko         Produk  Kuantitas  \
# 3    5   1/2/2020  TOKO APRILIA SUKRISNI  BATIK BESUREK        140
# 22  24   1/9/2020             Harya Sari  JAM LOKESWARA        200
# 50  52  1/14/2020                KARUNIA  JAM LOKESWARA        500
# 61  63  1/20/2020              TOKO AQIL  BATIK BESUREK         40
# 72  74  1/22/2020              TOKO IFAL  BATIK LONTARA        100
#
#     Pendapatan        Kota      Bujur  Lintang Code_Kota Benua    Provinsi  \
# 3    1162000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 22   2097000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 50   4920000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 61    332000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 72   2000000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
#
#    Prov_Code                     Lokasi Zona_Waktu    Provindi
# ...

# %%
#mengubah nilai kosong menggunakan mode
YOG_id["Prov_Code"]=YOG_id["Prov_Code"].fillna(YOG_id[(YOG_id["Provinsi"] == "Yogyakarta")]["Prov_Code"].mode()[0])
#df['Kategori'] = df['Kategori'].fillna(mode_value)
# Out:
# C:\Users\agian\AppData\Local\Temp/ipykernel_19340/933529234.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   YOG_id["Prov_Code"]=YOG_id["Prov_Code"].fillna(YOG_id[(YOG_id["Provinsi"] == "Yogyakarta")]["Prov_Code"].mode()[0])

# %%
#dfbaru.drop(['Prov_code'], axis=1, inplace=True)

# %%
#akhirnya nilai nan sudah terisi
YOG_id
# Out:
#     ID       Date              Name_Toko         Produk  Kuantitas  \
# 3    5   1/2/2020  TOKO APRILIA SUKRISNI  BATIK BESUREK        140
# 22  24   1/9/2020             Harya Sari  JAM LOKESWARA        200
# 50  52  1/14/2020                KARUNIA  JAM LOKESWARA        500
# 61  63  1/20/2020              TOKO AQIL  BATIK BESUREK         40
# 72  74  1/22/2020              TOKO IFAL  BATIK LONTARA        100
#
#     Pendapatan        Kota      Bujur  Lintang Code_Kota Benua    Provinsi  \
# 3    1162000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 22   2097000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 50   4920000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 61    332000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 72   2000000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
#
#    Prov_Code                     Lokasi Zona_Waktu    Provindi
# ...

# %%
#lanjut dengan simpan hasil ke data dfbaru
#penggabungan data dfbaru dengan Yog_id (cobinasi)
dfbaru['Prov_Code'].fillna(YOG_id['Prov_Code'], inplace=True)

# %%
dfbaru[(dfbaru['Lintang']  == -1.35790) & (dfbaru['Provinsi'] == 'Yogyakarta')]
# Out:
#     ID       Date              Name_Toko         Produk  Kuantitas  \
# 3    5   1/2/2020  TOKO APRILIA SUKRISNI  BATIK BESUREK        140
# 22  24   1/9/2020             Harya Sari  JAM LOKESWARA        200
# 50  52  1/14/2020                KARUNIA  JAM LOKESWARA        500
# 61  63  1/20/2020              TOKO AQIL  BATIK BESUREK         40
# 72  74  1/22/2020              TOKO IFAL  BATIK LONTARA        100
#
#     Pendapatan        Kota      Bujur  Lintang Code_Kota Benua    Provinsi  \
# 3    1162000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 22   2097000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 50   4920000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 61    332000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
# 72   2000000.0  Yogyakarta  102.25783  -1.3579        ID  Asia  Yogyakarta
#
#    Prov_Code                     Lokasi Zona_Waktu    Provindi
# ...

# %%
perubahan= dfbaru[dfbaru.isnull().any(axis=1)].sort_values(by='Kota', ascending=False)
perubahan
# Out:
#       ID       Date                Name_Toko         Produk  Kuantitas  \
# 65    67  1/21/2020         TOKO KIAN KIONG   JAM LOKESWARA       2000
# 70    72  1/22/2020                     ANDY  BATIK LONTARA        100
# 77    79  1/27/2020             TOKO HIDAYAH  JAM LOKESWARA        600
# 82    84   2/5/2020        TOKO WARUNG SANTI  JAM LOKESWARA        540
# 116  118  2/11/2020      TOKO JESAYA GINTING  JAM LOKESWARA      15000
# 67    69  1/21/2020   TOKO EKA SAPUTRA JAYA   JAM LOKESWARA       1000
# 110  112  2/10/2020        TOKO WARUNG SANTI  JAM LOKESWARA       1000
# 104  106   2/9/2020               TOKO BOB-i  JAM LOKESWARA        600
# 74    76  1/22/2020             Langkah Jaya  BATIK LONTARA        100
# 97    99   2/8/2020       TOKO ANDREAS INDAH  JAM LOKESWARA       3000
# 89    91   2/7/2020         TOKO JAYA MAKMUR  JAM LOKESWARA        540
# 62    64  1/20/2020              TOKO ABIZAR  JAM LOKESWARA        700
# ...

# %%
#mengubah nilai kosong menggunakan mode dari bebrapa provinsi
perubahan["Prov_Code"]=perubahan["Prov_Code"].fillna(perubahan[(perubahan["Provinsi"] == "Surabaya")]["Prov_Code"].mode())
#df['Kategori'] = df['Kategori'].fillna(mode_value)

# %%
dfbaru[(dfbaru['Kota'] == 'Surabaya')]
# Out:
#       ID       Date                                      Name_Toko  \
# 1      3   1/2/2020                          TOKO APRILIA SUKRISNI
# 21    23   1/7/2020  TOKO KOPERASI KONSUMEN SYARIAH BERKAH BERSEMI
# 41    43  1/10/2020                               Warung Nak Zihan
# 43    45  1/13/2020                                     TOKO MUNIR
# 49    51  1/13/2020                                  TOKO NURDIAH
# 53    55  1/16/2020                                     TOKO REVAN
# 57    59  1/20/2020                                   SAHABAT ANDA
# 60    62  1/20/2020                                      TOKO AQIL
# 65    67  1/21/2020                               TOKO KIAN KIONG
# 70    72  1/22/2020                                           ANDY
# 77    79  1/27/2020                                   TOKO HIDAYAH
# 79    81   2/5/2020                          TOKO YENNI SUSILAWATI
# 86    88   2/6/2020                         TOKO DIDIK PRIOJADMIKO
# ...

# %% [markdown]
# Ternyata memakai cara di atas cukup menyusahkan karena ada beberapa nilai dengat nilai kota, bujur/lintang sama tersapat hasil yang berbeda, premis 1 tidak bisa digunakan bila nilai provinsi lintang sama namun tidak pada kolom prov_code ysng memiliki nilsi berbeds.

# %% [markdown]
# **Analisis Data Tanpa melibatkan Kolom Provinsi dan Prov Code**

# %%
dfbaru.head(2)
# Out:
#    ID      Date              Name_Toko         Produk  Kuantitas  Pendapatan  \
# 0   2  1/2/2020             TOKO MURAH  BATIK LONTARA        120   8400000.0
# 1   3  1/2/2020  TOKO APRILIA SUKRISNI  JAM LOKESWARA       6000  62910000.0
#
#        Kota      Bujur  Lintang Code_Kota Benua    Provinsi Prov_Code  \
# 0   Bandung  107.61102 -6.92155        ID  Asia  Jawa Barat     ID-SU
# 1  Surabaya  112.73783 -7.24597        ID  Asia  Jawa Timur     ID-YO
#
#                        Lokasi  Zona_Waktu    Provindi
# 0  POINT (-6.92155 107.61102)   WIB+07:00  Jawa Barat
# 1  POINT (-7.24597 112.73783)  WITA+08:00  Jawa Timur

# %%
dfbaru.drop('ID', axis=1, inplace=True)

# %%
dfbaru['Produk'].value_counts()
# Out:
# JAM LOKESWARA     117
# BATIK LONTARA      36
#  JAM LOKESWARA     32
#  BATIK LONTARA     12
# BATIK BESUREK      10
# JAM WISH            8
#  JAM WISH           5
# JAM LOKES           1
#  BATIK BESUREK      1
# Name: Produk, dtype: int64

# %%
plt.figure(figsize=(15, 5))
ax = sns.countplot(x=dfbaru['Produk'])
ax.bar_label(ax.containers[0])
plt.show()

# %%
#melihat produk jam lokeswara dan mencoba melihat dari produk yang sama dengan pendapatan terbesar
dfbaru.loc[dfbaru['Produk'] == 'JAM LOKESWARA'].sort_values(by='Pendapatan', ascending = False)
# Out:
#           Date              Name_Toko         Produk  Kuantitas   Pendapatan  \
# 101   2/9/2020    TOKO JESAYA GINTING  JAM LOKESWARA      15000  157500000.0
# 108  2/10/2020  TOKO BERKAH DUA PUTRA  JAM LOKESWARA      15000  157500000.0
# 91    2/7/2020  TOKO BERKAH DUA PUTRA  JAM LOKESWARA      15000  157500000.0
# 116  2/11/2020    TOKO JESAYA GINTING  JAM LOKESWARA      15000  157500000.0
# 147  2/20/2020    TOKO ANDRI SUGIANTO  JAM LOKESWARA      15000  157500000.0
# ..         ...                    ...            ...        ...          ...
# 73   1/22/2020           Langkah Jaya  JAM LOKESWARA        200    1968000.0
# 14    1/6/2020             TOKO FAHRI  JAM LOKESWARA        200    1968000.0
# 34   1/13/2020             TOKO FAHRI  JAM LOKESWARA        200    1968000.0
# 95    2/8/2020  TOKO YENNI SUSILAWATI  JAM LOKESWARA         80     840000.0
# 112  2/11/2020  TOKO YENNI SUSILAWATI  JAM LOKESWARA         80     840000.0
#
# ...

# %% [markdown]
# Dapat kita simpulkan sidini bahwasannya produk yang paling laris adalah JAM  LOKESWARA

# %%
dfbaru['Pendapatan'].max()
# Out:
# 157500000.0

# %%
#pendapatan terbesar
dfbaru[(dfbaru['Pendapatan'] == 157500000.0)]
# Out:
#           Date              Name_Toko         Produk  Kuantitas   Pendapatan  \
# 91    2/7/2020  TOKO BERKAH DUA PUTRA  JAM LOKESWARA      15000  157500000.0
# 101   2/9/2020    TOKO JESAYA GINTING  JAM LOKESWARA      15000  157500000.0
# 108  2/10/2020  TOKO BERKAH DUA PUTRA  JAM LOKESWARA      15000  157500000.0
# 116  2/11/2020    TOKO JESAYA GINTING  JAM LOKESWARA      15000  157500000.0
# 147  2/20/2020    TOKO ANDRI SUGIANTO  JAM LOKESWARA      15000  157500000.0
#
#            Kota      Bujur  Lintang Code_Kota Benua   Provinsi Prov_Code  \
# 91      Jakarta  106.82274 -6.17447        ID  Asia    Jakarta     ID-JI
# 101     Bandung  107.61102 -6.92155        ID  Asia    Jakarta     ID-JI
# 108  Yogyakarta  102.25783 -1.35790        ID  Asia    Jakarta     ID-JI
# 116   Pontianak  109.34475 -0.02269        ID  Asia  Pontianak       NaN
# 147    Makassar  106.87699 -6.27608        ID  Asia   Sulawesi        ID
#
#                          Lokasi  Zona_Waktu          Provindi
# ...

# %% [markdown]
# Dapat dilihat dari beberapa toko dan kota yang menghasilkan pendapatan terbanyak

# %%
#melihat hubgan antara kuantitas dengan pendapatan apakah dari kedua ini memiliki hubungan
#menggunakan headmap
plt.figure(figsize=(20,10))
sns.heatmap(dfbaru.corr(), annot=True, cmap='PuBu') #GnBu, PuBu, YlGnBu, RdPu, YlGn
plt.show()

# %% [markdown]
# ternyata benar dari kolom kuantitas memiliki hubungan yang sangat signifikan dengan kolom pendapatan

# %%
dfbaru.hist(figsize=(15,15), bins=30, color='c')
# Out:
# array([[<AxesSubplot: title={'center': 'Kuantitas'}>,
#         <AxesSubplot: title={'center': 'Pendapatan'}>],
#        [<AxesSubplot: title={'center': 'Bujur'}>,
#         <AxesSubplot: title={'center': 'Lintang'}>]], dtype=object)

# %%
plt.figure(figsize=(20,15))
ax= dfbaru['Kuantitas'].value_counts(ascending=True).plot(kind='barh',color='blue')
ax.bar_label(ax.containers[0])
plt.show()

# %%
dfbaru.Kuantitas.max()
# Out:
# 18000

# %%
dfbaru[(dfbaru['Kuantitas'] == 18000)]
# Out:
#           Date               Name_Toko         Produk  Kuantitas  Pendapatan  \
# 80    2/5/2020            TOKO HARYATI  JAM LOKESWARA      18000   3100000.0
# 87    2/6/2020              TOKO BOB-i  JAM LOKESWARA      18000   3100000.0
# 157  2/21/2020  TOKO ENDANG SUSILAWATI  JAM LOKESWARA      18000   3100000.0
#
#             Kota      Bujur  Lintang Code_Kota Benua    Provinsi Prov_Code  \
# 80    Yogyakarta  102.25783 -1.35790        ID  Asia     Jakarta     ID-JI
# 87    Yogyakarta  102.25783 -1.35790        ID  Asia     Jakarta     ID-JI
# 157  Banjarmasin  114.59258 -3.31875        ID  Asia  Kalimantan        ID
#
#                          Lokasi  Zona_Waktu    Provindi
# 80    POINT (-1.3579 102.25783)   WIB+07:00  Jawa Barat
# 87    POINT (-1.3579 102.25783)   WIB+07:00  Jawa Barat
# 157  POINT (-3.31875 114.59258)  WITA+08:00           0

# %%
dfbaru.loc[dfbaru['Kuantitas'] == 500].sort_values(by='Pendapatan', ascending=False)
# Out:
#             Date                                      Name_Toko  \
# 63     1/21/2020                               TOKO SARDIYANTO
# 176   2020-02-25                           TOKO QOYIM MASYAHARI
# 125     2/7/2020                               TOKO SRI WAHYUNI
# 84      2/6/2020                            TOKO JESAYA GINTING
# 50     1/14/2020                                        KARUNIA
# 12      1/6/2020                           TOKO FATHULLAH ZIKRI
# 54     1/16/2020                                   TOKO DOA IBU
# 10      1/6/2020                                       TOKO DEB
# 37     1/14/2020                                TOKO KEDAI YUDA
# 32     1/13/2020                           TOKO FATHULLAH ZIKRI
# 30     1/13/2020                                       TOKO DEB
# 19      1/7/2020  TOKO KOPERASI KONSUMEN SYARIAH BERKAH BERSEMI
# 17      1/7/2020                                TOKO KEDAI YUDA
# 167    2/25/2020                                 TOKO SILVIANA
# ...

# %% [markdown]
# kuantitas produk terbanyak adalah **500** dengan pendapatan tetinggi yaitu **5250000** dan juga dapat melihat toko apa saja yang memiliki data tersebut, rata - rata produk Jam lokeswara

# %%
fig = plt.figure(figsize = (20,16))

# Plotting boxplots
nbin_var = dfbaru[['Kuantitas', 'Pendapatan']]
for i, v in enumerate(nbin_var):
    axes = fig.add_subplot(4, 2, i+1)
    sns.boxplot(x = v, data = dfbaru, ax = axes, color='#8FBC8F')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19340/3855340663.py in <module>
#       1 # Box plot
# ----> 2 dfnormal['Kuantitas'].plot.box(
#       3     showfliers = False,
#       4     grid = True,
#       5     figsize = (10, 7)
#
# NameError: name 'dfnormal' is not defined

# %%
# Box plot
dfbaru['Kuantitas'].plot.box(
    showfliers = False,
    grid = True,
    figsize = (10, 7)
)
plt.suptitle("outlier kuantitas")
plt.show()

# %% [markdown]
# Dari boxplot di atas terdapat outlier, outlier itu sendiri tidak perlu dihilangkan karena data tersebut sangat berperan penting kecuali memang benar benar berpengaruh maka outlier perlu diatasi
# dan diliat dari boxplot juga dapat diketahui bahwa dari kuantitas 500 sampai dengan 1000/1200 itu merupakan data yang paling banyak

# %%
# Scatter plot antara 'Kuantitas' dan 'Pendapatan'
plt.figure(figsize=(10, 6))
ax = plt.scatter(dfbaru['Kuantitas'], dfbaru['Pendapatan'], s=10)
# Menambahkan label pada setiap titik
for i, txt in enumerate(dfbaru.index):
    plt.annotate(txt, (dfbaru['Kuantitas'][i], dfbaru['Pendapatan'][i]), xytext=(5, 5), textcoords='offset points')
# Memberikan label sumbu
plt.xlabel('Kuantitas')
plt.ylabel('Pendapatan')

# Menampilkan judul plot
plt.title('Scatter Plot Kuantitas vs Pendapatan')

# Menampilkan plot
plt.show()

# %%
dfbaru.sort_values(by='Kuantitas', inplace=True)

# Membuat diagram garis
plt.figure(figsize=(10, 6))
plt.plot(dfbaru['Kuantitas'], dfbaru['Pendapatan'], marker='o', linestyle='-', color='b')
plt.title('Diagram Garis antara Pendapatan dan Kuantitas')
plt.xlabel('Kuantitas')
plt.ylabel('Pendapatan')
plt.grid(True)
plt.show()

# %% [markdown]
# pendapat tinggi juga dipengaruhi oleh jumlah kuantitas namun ada beberapa data dengan kuantitas tinggi mendapatkan pendapatan yang kecil dapat dilihat dari diagram diatas ada beberapa nilai atau titik terpisah dari rombongannya mari kita analisis

# %%
#karena nilai tidak bisa terlihat (perkecil jumlah data agar)
# Mengambil data dari indeks 0 sampai 50
dfsor=dfbaru.iloc[0:50]
dfsor
# Out:
#             Date                                      Name_Toko  \
# 185   2020-07-27        YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI
# 25      1/9/2020                                     Harya Sari
# 132    2/11/2020                              TOKO RIZKI SAKYAH
# 51     1/14/2020                                        KARUNIA
# 134    2/11/2020                              TOKO RIZKI SAKYAH
# 140    2/17/2020                                      TOKO IRVA
# 136    2/12/2020                                    TOKO RAHMAD
# 55     1/16/2020                                   TOKO DOA IBU
# 35     1/13/2020                                     TOKO FAHRI
# 170    2/25/2020                                 TOKO SILVIANA
# 15      1/6/2020                                     TOKO FAHRI
# 53     1/16/2020                                     TOKO REVAN
# 194   2021-04-03                                     TOKO SIDAK
# 61     1/20/2020                                      TOKO AQIL
# ...

# %%
# Scatter plot antara 'Kuantitas' dan 'Pendapatan'
plt.figure(figsize=(10, 6))
ax = plt.scatter(dfsor['Kuantitas'], dfsor['Pendapatan'], s=10)

# Menambahkan label pada setiap titik
for i, txt in enumerate(dfsor.index):
    plt.annotate(str(txt), (dfsor['Kuantitas'].iloc[i], dfsor['Pendapatan'].iloc[i]), xytext=(5, 5), textcoords='offset points')
# Memberikan label sumbu
plt.xlabel('Kuantitas')
plt.ylabel('Pendapatan')

# Menampilkan judul plot
plt.title('Scatter Plot Kuantitas vs Pendapatan')

# Menampilkan plot
plt.show()

# %% [markdown]
# mulai sedikit tampil dalam indek 13 dan 11 berikuti ini memiliki kuantitasz rendah namun pendapatan tinggi

# %%
# dikarenakan nilai indek tidak berurutan maka menginputdata dengan satu persatu
indeks_baris = [11, 31]  # Indeks baris dimulai dari 0
#mencari nilai kolom
dfbaru.loc[indeks_baris]
# Out:
#          Date Name_Toko         Produk  Kuantitas  Pendapatan       Kota  \
# 11   1/6/2020  TOKO DEB  BATIK LONTARA        100  20000000.0  Pontianak
# 31  1/13/2020  TOKO DEB  BATIK LONTARA        100  20000000.0  Pontianak
#
#         Bujur  Lintang Code_Kota Benua          Provinsi Prov_Code  \
# 11  109.34475 -0.02269        ID  Asia  Kalimantan Barat     ID-SU
# 31  109.34475 -0.02269        ID  Asia  Kalimantan Barat     ID-SA
#
#                         Lokasi Zona_Waktu          Provindi
# 11  POINT (-0.02269 109.34475)  WIB+07:00  Kalimantan Barat
# 31  POINT (-0.02269 109.34475)  WIB+07:00  Kalimantan Barat

# %%
#dari hasil data diperkecil maka mulai terlihat index yang terdapat pada grafik
#untuk memastikan apakah tidak adalagi data selain indek 11 dan 31
df_kb = dfbaru[(dfbaru['Pendapatan'] >= 20000000.0) & (dfbaru['Kuantitas'] == 100)]
df_kb
# Out:
#          Date Name_Toko         Produk  Kuantitas  Pendapatan       Kota  \
# 31  1/13/2020  TOKO DEB  BATIK LONTARA        100  20000000.0  Pontianak
# 11   1/6/2020  TOKO DEB  BATIK LONTARA        100  20000000.0  Pontianak
#
#         Bujur  Lintang Code_Kota Benua          Provinsi Prov_Code  \
# 31  109.34475 -0.02269        ID  Asia  Kalimantan Barat     ID-SA
# 11  109.34475 -0.02269        ID  Asia  Kalimantan Barat     ID-SU
#
#                         Lokasi Zona_Waktu          Provindi
# 31  POINT (-0.02269 109.34475)  WIB+07:00  Kalimantan Barat
# 11  POINT (-0.02269 109.34475)  WIB+07:00  Kalimantan Barat

# %% [markdown]
# lanjut analisis pada nilai pendapatan rendah namun Kuantitas tinggi

# %%
dfkuti = dfbaru.iloc[50:150]

# %%
# Scatter plot antara 'Kuantitas' dan 'Pendapatan'
plt.figure(figsize=(10, 6))
scatter = plt.scatter(dfkuti['Kuantitas'], dfkuti['Pendapatan'], s=10)

# Menambahkan label pada setiap titik
for i, txt in enumerate(dfkuti.index):
    plt.annotate(str(txt), (dfkuti['Kuantitas'].iloc[i], dfkuti['Pendapatan'].iloc[i]), xytext=(5, 5), textcoords='offset points')

# Memberikan label sumbu
plt.xlabel('Kuantitas')
plt.ylabel('Pendapatan')

# Menampilkan judul plot
plt.title('Scatter Plot Kuantitas vs Pendapatan')

# Menampilkan plot
plt.show()

# %%
#diketahui dari awal keanehan berada pada index 144 
dfbaru.loc[144][['Kuantitas', 'Pendapatan']]
# Out:
# Kuantitas           2000
# Pendapatan    12000000.0
# Name: 144, dtype: object

# %%
#analisis data kuantitas besar namun pendapatan kecil
df_bk = dfbaru[(dfbaru['Pendapatan'] <= 12000000.0) & (dfbaru['Kuantitas'] >= 2000)]
df_bk.sort_values(by = 'Kuantitas', ascending=False)
# Out:
#             Date               Name_Toko          Produk  Kuantitas  \
# 87      2/6/2020              TOKO BOB-i   JAM LOKESWARA      18000
# 157    2/21/2020  TOKO ENDANG SUSILAWATI   JAM LOKESWARA      18000
# 80      2/5/2020            TOKO HARYATI   JAM LOKESWARA      18000
# 75     1/23/2020    TOKO ANDRI SUGIANTO    JAM LOKESWARA      10000
# 162    2/21/2020          TOKO ANTONIUS    JAM LOKESWARA      10000
# 76     1/23/2020    TOKO JESAYA GINTING    JAM LOKESWARA      10000
# 124     2/7/2020     TOKO JESAYA GINTING   JAM LOKESWARA      10000
# 145    2/20/2020  TOKO SYARBINUS PANGKAS   JAM LOKESWARA       8000
# 130    2/10/2020      TOKO FAKHLI HARUDI   JAM LOKESWARA       8000
# 102     2/9/2020  TOKO ENDANG SUSILAWATI   JAM LOKESWARA       6000
# 119     2/6/2020        TOKO DIANA RISTA   JAM LOKESWARA       6000
# 117    2/11/2020  TOKO ENDANG SUSILAWATI   JAM LOKESWARA       6000
# 92      2/7/2020  TOKO ENDANG SUSILAWATI   JAM LOKESWARA       6000
# ...

# %%
df_bk.shape
# Out:
# (18, 15)

# %% [markdown]
# Dari data di atas dapat dikatui pendapatan kecil dengan Kuantitas yng besar

# %%
#penggabungan data besar dan kecil
df_total = pd.concat([df_bk, df_kb], axis=0)
df_total
# Out:
#             Date               Name_Toko          Produk  Kuantitas  \
# 144    2/20/2020      TOKO SIGID PAMBUDI   JAM LOKESWARA       2000
# 66     1/21/2020     TOKO ANDREAS INDAH    JAM LOKESWARA       4000
# 171   2020-02-25         TOKO KIAN KIONG   JAM LOKESWARA       4000
# 159    2/21/2020       TOKO DIANA RISTA    JAM LOKESWARA       4000
# 109    2/10/2020  TOKO ENDANG SUSILAWATI   JAM LOKESWARA       6000
# 92      2/7/2020  TOKO ENDANG SUSILAWATI   JAM LOKESWARA       6000
# 117    2/11/2020  TOKO ENDANG SUSILAWATI   JAM LOKESWARA       6000
# 119     2/6/2020        TOKO DIANA RISTA   JAM LOKESWARA       6000
# 102     2/9/2020  TOKO ENDANG SUSILAWATI   JAM LOKESWARA       6000
# 130    2/10/2020      TOKO FAKHLI HARUDI   JAM LOKESWARA       8000
# 145    2/20/2020  TOKO SYARBINUS PANGKAS   JAM LOKESWARA       8000
# 124     2/7/2020     TOKO JESAYA GINTING   JAM LOKESWARA      10000
# 76     1/23/2020    TOKO JESAYA GINTING    JAM LOKESWARA      10000
# ...

# %%
df_total.shape
# Out:
# (20, 15)

# %%
df_total.Name_Toko.value_counts().plot(kind='bar')
plt.title("Nama toko yang mengalami penurunan")
# Out:
# Text(0.5, 1.0, 'Nama toko yang mengalami penurunan')

# %%
df_total.Kota.value_counts().plot(kind='bar')
plt.title("Nama toko yang mengalami penurunan")
# Out:
# Text(0.5, 1.0, 'Nama toko yang mengalami penurunan')

# %% [markdown]
# Kota yang mengalami banyak Penurunana pendapatan

# %%
df_total.Zona_Waktu.value_counts().plot(kind='bar')
plt.title("Nama toko yang mengalami penurunan")
# Out:
# Text(0.5, 1.0, 'Nama toko yang mengalami penurunan')

# %%
df_total['Date'] = pd.to_datetime(df_total['Date'])

# %%
df_total['Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# dapat diketahui data yang mengalami keanehan itu banyak di tahun 2020

# %%
#agar data tidak mengalami kerusakan harus mengubahnya terllebih dahulu dengan membuat nama baru
dfnormal = dfbaru

# %%
dfnormal.shape
# Out:
# (222, 15)

# %%
dfnormal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 185 to 87
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        222 non-null    object
#  1   Name_Toko   222 non-null    object
#  2   Produk      222 non-null    object
#  3   Kuantitas   222 non-null    int64
#  4   Pendapatan  222 non-null    float64
#  5   Kota        222 non-null    object
#  6   Bujur       222 non-null    float64
#  7   Lintang     222 non-null    float64
#  8   Code_Kota   222 non-null    object
#  9   Benua       222 non-null    object
#  10  Provinsi    222 non-null    object
#  11  Prov_Code   197 non-null    object
#  12  Lokasi      222 non-null    object
#  13  Zona_Waktu  222 non-null    object
#  14  Provindi    222 non-null    object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 35.9+ KB

# %%
dfnormal['Date'] = pd.to_datetime(dfnormal['Date'])

# %%
# Menggabungkan df_1 dan df_2
merged_df = pd.merge(dfnormal, df_total, how='outer', indicator=True)

# Menyaring baris yang hanya terdapat pada df_1
result_df = merged_df.query("_merge == 'left_only'").drop(columns=['_merge'])

# Menampilkan hasil pengurangan
print("hasil dfnormal 222, 14 dikurangi df_total 20, 14")
result_df
# Out:
# hasil dfnormal 222, 14 dikurangi df_total 20, 14
#           Date                                 Name_Toko          Produk  \
# 0   2020-07-27   YAYASAN KESEJAHTERAAN PEGAWAI (YKP) BNI   JAM LOKESWARA
# 1   2020-01-09                                Harya Sari        JAM WISH
# 2   2020-02-11                         TOKO RIZKI SAKYAH   BATIK LONTARA
# 3   2020-01-14                                   KARUNIA   BATIK LONTARA
# 4   2020-02-11                         TOKO RIZKI SAKYAH   BATIK BESUREK
# ..         ...                                       ...             ...
# 214 2020-02-20                       TOKO ANDRI SUGIANTO   JAM LOKESWARA
# 215 2020-02-09                       TOKO JESAYA GINTING   JAM LOKESWARA
# 216 2020-02-10                     TOKO BERKAH DUA PUTRA   JAM LOKESWARA
# 217 2020-02-11                       TOKO JESAYA GINTING   JAM LOKESWARA
# 218 2020-02-07                     TOKO BERKAH DUA PUTRA   JAM LOKESWARA
#
# ...

# %% [markdown]
# dari tabel di atasi merupakan tabel normal dengan asumsi apabila Kuantitas menambah/naik maka pendapatan akan terus meningkat

# %%
ax = dfnormal['Date'].dt.year.value_counts().plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.title("label pendapatan NORMALdalam dari tahun")
plt.show()

# %% [markdown]
# toko produkti dari tahun 2020-2023 namun paling banyak penjualan itu pada tahun 2020

# %%
plt.figure(figsize=(20,10))
ax = dfnormal['Kota'].value_counts().plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.title("label pendapatan NORMALberdasarkan Kota")
plt.show()

# %% [markdown]
# dari visualisai diatas diketahui surabaya merupakan kota terbanyak yang ada dalam data normal

# %%
Nor_pen = dfnormal.groupby('Kota')['Pendapatan'].sum().sort_values(ascending=False)
Nor_pen
# Out:
# Kota
# Jakarta         322667050.0
# Bandung         302203100.0
# Medan           284420600.0
# Yogyakarta      277255000.0
# Pontianak       277169800.0
# Surabaya        233308000.0
# Makassar        220500000.0
# Denpasar        146794200.0
# Makasar          97345600.0
# Banjarmasin      85350000.0
# Surakarta        58019200.0
# Semarang         57873400.0
# Tangerang        52500000.0
#  Jayapura        43805300.0
#  Manado          41379300.0
#  Ambon           40228700.0
#  Pontianak       35620400.0
#  Denpasar        31500000.0
# Lampung          29600000.0
#  Padang          29503600.0
#  Bandung         27300000.0
# Batam            25590000.0
# Padang           25590000.0
# Palembang        23010000.0
#  Jakarta         15750000.0
# Samarinda        15400000.0
# Depok            15073000.0
# Mataram          14760000.0
#  Yogyakarta      10500000.0
#  Surakarta       10500000.0
#  Makasar          9800000.0
#  Palembang        9450000.0
# Pekanbaru         8400000.0
# ...

# %%
plt.figure(figsize=(27, 10))
Nor_pen.plot(kind='barh',color='blue')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# Kota Jakarta merupakan kota dengan pendapatan terbanyak

# %%
#mari kita lihat penyebaran data dalam kota makasar
dfnormal[(dfnormal['Kota'] == 'Jakarta')]['Pendapatan'].sum()
# Out:
# 322667050.0

# %%
dfnormal[(dfnormal['Kota'] == 'Bandung')]['Pendapatan'].sum()
# Out:
# 302203100.0

# %%
dfnormal[(dfnormal['Kota'] == 'Medan')]['Pendapatan'].sum()
# Out:
# 284420600.0

# %%
dfnormal[(dfnormal['Kota'] == 'Malang')]['Pendapatan'].sum()
# Out:
# 3320000.0

# %% [markdown]
# Dari penjelasan di atas diketahui pendapatan **Jakarta** lebih tinggi yaitu **322.667.050** juta kemudian kedua disusul oleh **Bandung** dengan pendapatan **302.203.100**, **Medan 284.420.600**. Sedangkan pendapatan kecil itu terletak pasa kota **Malang 3.320.000**

# %%
# Assuming dfnormal is your DataFrame
idxmax_rows = dfnormal.groupby('Kota')['Pendapatan'].idxmax()

# Extract the rows with the highest 'Pendapatan' for each 'Kota'
max_pendapatan_rows = dfnormal.loc[idxmax_rows]

# Display the result
max_pendapatan_rows.sort_values(by='Pendapatan', ascending = False)
# Out:
#           Date                     Name_Toko          Produk  Kuantitas  \
# 91  2020-02-07         TOKO BERKAH DUA PUTRA   JAM LOKESWARA      15000
# 101 2020-02-09           TOKO JESAYA GINTING   JAM LOKESWARA      15000
# 108 2020-02-10         TOKO BERKAH DUA PUTRA   JAM LOKESWARA      15000
# 147 2020-02-20           TOKO ANDRI SUGIANTO   JAM LOKESWARA      15000
# 116 2020-02-11           TOKO JESAYA GINTING   JAM LOKESWARA      15000
# 146 2020-02-20                  TOKO SUKARDI   JAM LOKESWARA       7300
# 47  2020-01-13           TOKO ANDREAS INDAH    JAM LOKESWARA       7000
# 149 2020-02-20                TOKO AGUSTINUS   JAM LOKESWARA       6400
# 1   2020-01-02         TOKO APRILIA SUKRISNI   JAM LOKESWARA       6000
# 126 2020-02-10              TOKO DEWI AFRITA   JAM LOKESWARA       5000
# 155 2020-02-20         TOKO EKA SAPUTRA JAYA   JAM LOKESWARA       5000
# 156 2020-02-21  TOKO FEBRIANTI INDAH LESTARI   JAM LOKESWARA       3500
# ...

# %% [markdown]
# Data di atas ini Melihat data pendapatan tertinggi berdasarkan Kota

# %%
plt.figure(figsize=(27, 10))
ax = sns.countplot(x=dfnormal['Name_Toko'], palette='viridis')
ax.bar_label(ax.containers[0])
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.title('Distribution of Name_Toko', fontsize=20)# Rotation and alignment adjustment
plt.xlabel('Nama Toko', fontsize=20)
plt.ylabel('Count', fontsize=20)
plt.show()

# %%
order = dfnormal['Name_Toko'].value_counts().index
plt.figure(figsize=(27, 10))
sns.countplot(x='Name_Toko', data=dfnormal, palette='plasma', order=order) #palet(viridis, magma, plasma)
plt.xticks(rotation=45, ha='right', fontsize=12)                        #mako, rocket
plt.title('Distribution of Name_Toko', fontsize=20)
plt.show()

# %% [markdown]
# dari visualisai diatas dapat di ketahui nama toko **Toko Warung Santi** terbanyak dalam data normal

# %%
pen_Toko = dfnormal.groupby('Name_Toko')['Pendapatan'].sum().sort_values(ascending=False)
pen_Toko
# Out:
# Name_Toko
# TOKO JESAYA GINTING      322692500.0
# TOKO BERKAH DUA PUTRA    315000000.0
# TOKO ANDRI SUGIANTO      157500000.0
# TOKO DEWI AFRITA         105000000.0
# TOKO ANDREAS INDAH        94850000.0
#                             ...
# Langkah Jaya               3968000.0
# Warung Nak Zihan           3497600.0
# TOKO JESAYA GINTING        2500000.0
# TOKO ANTONIUS              2500000.0
# TOKO ANDRI SUGIANTO        2500000.0
# Name: Pendapatan, Length: 102, dtype: float64

# %%
plt.figure(figsize=(40, 30))
pen_Toko.plot(kind='barh',color='blue')
ax.bar_label(ax.containers[0])
plt.show()

# %%
dfnormal[(dfnormal['Name_Toko'] == 'TOKO JESAYA GINTING') | (dfnormal['Name_Toko'] == 'TOKO BERKAH DUA PUTRA')]
# Out:
#           Date              Name_Toko         Produk  Kuantitas   Pendapatan  \
# 84  2020-02-06    TOKO JESAYA GINTING  JAM LOKESWARA        500    5192500.0
# 124 2020-02-07    TOKO JESAYA GINTING  JAM LOKESWARA      10000    2500000.0
# 101 2020-02-09    TOKO JESAYA GINTING  JAM LOKESWARA      15000  157500000.0
# 108 2020-02-10  TOKO BERKAH DUA PUTRA  JAM LOKESWARA      15000  157500000.0
# 116 2020-02-11    TOKO JESAYA GINTING  JAM LOKESWARA      15000  157500000.0
# 91  2020-02-07  TOKO BERKAH DUA PUTRA  JAM LOKESWARA      15000  157500000.0
#
#            Kota      Bujur  Lintang Code_Kota Benua   Provinsi Prov_Code  \
# 84      Jakarta  106.82274 -6.17447        ID  Asia    Jakarta     ID-JI
# 124   Palembang  104.75686 -2.98883        ID  Asia    Sumatra        ID
# 101     Bandung  107.61102 -6.92155        ID  Asia    Jakarta     ID-JI
# 108  Yogyakarta  102.25783 -1.35790        ID  Asia    Jakarta     ID-JI
# ...

# %% [markdown]
# Berdasarkan nama toko dengan pendapatan berdasarkan jumlah(sum) dari visualisai di atas dapat diketahui **TOKO JESAYA GINTING dan TOKO BERKAH DUA PUTRA** memiliki pendapatan yang tinggi

# %%
dfnormal['Kota'].unique()
# Out:
# array([' Padang', 'Jakarta', 'Bandung', 'Semarang', 'Pontianak',
#        'Lampung', 'Surabaya', ' Ambon', 'Yogyakarta', 'Makasar',
#        'Pekanbaru', ' Jayapura', 'Denpasar', ' Pontianak', 'Surakarta',
#        'Banjarmasin', ' Manado', 'Samarinda', 'palembang', 'Palembang',
#        ' Makasar', 'Malang', 'Medan', 'Jayapura', ' Banjarmasin', 'Batam',
#        'Depok', 'Padang', 'Mataram', ' Semarang', 'Bekasi', ' Palembang',
#        ' Yogyakarta', ' Surakarta', 'Makassar', ' Jakarta', ' Bandung',
#        ' Denpasar', ' Medan', 'Tangerang'], dtype=object)

# %%
#Ambil 5 Product Populer Untuk Sebagai Acuan Terhadap Penjualan Product Tersebut Dari Waktu Ke Waktu
# Regroup for top 5 items
#Dari penjelasan di atas diketahui pendapatan Jakarta lebih tinggi yaitu 322.667.050 juta kemudian kedua disusul oleh
#Bandung dengan pendapatan 302.203.100, Medan 284.420.600.
date_item_df = pd.DataFrame(
    dfnormal.loc[
        dfnormal['Kota'].isin(['Jakarta', 'Bandung', 'Medan', 'Yogyakarta', 'Pontianak'])
    ].set_index('Date').groupby([
        pd.Grouper(freq='M'), 'Kota'
    ])['Pendapatan'].sum()
)
date_item_df
# Out:
#                         Pendapatan
# Date       Kota
# 2020-01-31 Bandung      49927000.0
#            Jakarta      39843500.0
#            Medan        21712200.0
#            Pontianak    60550000.0
#            Yogyakarta   10511000.0
# 2020-02-29 Bandung     252276100.0
#            Jakarta     282823550.0
#            Medan       262708400.0
#            Pontianak   216619800.0
#            Yogyakarta  266744000.0

# %%
#Ubah Tampilan Perbandingan Tersebut Menjadi Tabel Sehingga Lebih Mudah Untuk Melakukan Analisa Terhadap Product Tersebut
trending_itmes_df = date_item_df.reset_index().pivot('Date','Kota').fillna(0)

trending_itmes_df = trending_itmes_df.reset_index()
trending_itmes_df = trending_itmes_df.set_index('Date')
trending_itmes_df.columns = trending_itmes_df.columns.droplevel(0)

trending_itmes_df
# Out:
# Kota            Bandung      Jakarta        Medan    Pontianak   Yogyakarta
# Date
# 2020-01-31   49927000.0   39843500.0   21712200.0   60550000.0   10511000.0
# 2020-02-29  252276100.0  282823550.0  262708400.0  216619800.0  266744000.0

# %%
#Lakukan Perbandingan Terhadap Ke 5 Product Tersebut Ke Dalam Grafik

ax = pd.DataFrame(trending_itmes_df.values).plot(
    figsize=(10,7),
    grid=True,
)

ax.set_ylabel('number of purchases')
ax.set_xlabel('date')
ax.set_title('Item Trends over Time')

ax.legend(trending_itmes_df.columns, loc='upper left')

plt.xticks(
    range(len(trending_itmes_df.index)), 
    [x.strftime('%m.%Y') for x in trending_itmes_df.index], 
    rotation=45
)

plt.show()
